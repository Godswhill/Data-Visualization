# %% [markdown]
# # ASSIGNMENT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing the csv file

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\customers.csv")

# %%
data
# Out:
#        CustomerKey Prefix  FirstName LastName              Unnamed: 4  \
# 0            11000    MR.        JON     YANG            MR. JON YANG
# 1            11001    MR.     EUGENE    HUANG        MR. EUGENE HUANG
# 2            11002    MR.      RUBEN   TORRES        MR. RUBEN TORRES
# 3            11003    MS.    CHRISTY      ZHU         MS. CHRISTY ZHU
# 4            11004   MRS.  ELIZABETH  JOHNSON  MRS. ELIZABETH JOHNSON
# ...            ...    ...        ...      ...                     ...
# 18143        29479    MR.      TOMMY     TANG          MR. TOMMY TANG
# 18144        29480   MRS.       NINA     RAJI          MRS. NINA RAJI
# 18145        29481    MR.       IVAN     SURI           MR. IVAN SURI
# 18146        29482    MR.    CLAYTON    ZHANG       MR. CLAYTON ZHANG
# 18147        29483    MR.      JÉSUS  NAVARRO       MR. JÉSUS NAVARRO
#
#       Unnamed: 5 Unnamed: 6   BirthDate  Unnamed: 8 MaritalStatus Gender  \
# ...

# %%
data.isna().sum()
# Out:
# CustomerKey           0
# Prefix              130
# FirstName             0
# LastName              0
# Unnamed: 4            0
# Unnamed: 5            0
# Unnamed: 6        18102
# BirthDate             0
# Unnamed: 8        18148
# MaritalStatus         0
# Gender              130
# EmailAddress          0
# AnnualIncome          0
# TotalChildren         0
# EducationLevel        0
# Occupation            0
# HomeOwner             0
# Unnamed: 17       18148
# Unnamed: 18       18148
# BirthDate.1       18146
# dtype: int64

# %% [markdown]
# dropping unwanted columns

# %%
data.columns
# Out:
# Index(['CustomerKey', 'Prefix', 'FirstName', 'LastName', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'BirthDate', 'Unnamed: 8', 'MaritalStatus',
#        'Gender', 'EmailAddress', 'AnnualIncome', 'TotalChildren',
#        'EducationLevel', 'Occupation', 'HomeOwner', 'Unnamed: 17',
#        'Unnamed: 18', 'BirthDate.1'],
#       dtype='object')

# %%
y = ['FirstName', 'LastName','Unnamed: 5', 'Unnamed: 6','Prefix','Unnamed: 8','Unnamed: 17',
       'Unnamed: 18']

# %%
data.drop(y, axis = 1, inplace = True)

# %%
data
# Out:
#        CustomerKey              Unnamed: 4   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %% [markdown]
# filling the voids

# %%
data.fillna(method = "ffill", inplace = True)

# %%
data
# Out:
#        CustomerKey              Unnamed: 4   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %%
data.drop("BirthDate.1", axis = 1, inplace = True)

# %%
data
# Out:
#        CustomerKey              Unnamed: 4   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %% [markdown]
# Renaming columns

# %%
data.rename(columns={'Unnamed: 4':'Full Name'},inplace = True)

# %%
data
# Out:
#        CustomerKey               Full Name   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %% [markdown]
# converting annual income to int by removing the strings characteristics

# %%
data.AnnualIncome = data.AnnualIncome.str.strip("$")

# %%
data.AnnualIncome = data.AnnualIncome.str.replace(",", "")

# %%
data
# Out:
#        CustomerKey               Full Name   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %% [markdown]
# changing values in a column

# %%
data.MaritalStatus = data.MaritalStatus.str.replace("M", "Married")
data.MaritalStatus = data.MaritalStatus.str.replace("S","Single")
data.HomeOwner = data.HomeOwner.str.replace("Y","Yes")
data.HomeOwner = data.HomeOwner.str.replace("N","No")

# %%
data
# Out:
#        CustomerKey               Full Name   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966       Married      M
# 1            11001        MR. EUGENE HUANG  14/05/1965        Single      M
# 2            11002        MR. RUBEN TORRES   8/12/1965       Married      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968        Single      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968        Single      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958       Married      M
# 18144        29480          MRS. NINA RAJI  11/10/1960        Single      F
# 18145        29481           MR. IVAN SURI    1/5/1960        Single      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959       Married      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959       Married      M
#
# ...

# %% [markdown]
# converting BirthDate to datetime

# %%
data.BirthDate = pd.to_datetime(data.BirthDate, format = "mixed")

# %%
data.BirthDate = pd.to_datetime(data.BirthDate, format = "%d-%m-%Y")

# %%
data
# Out:
#        CustomerKey               Full Name  BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG 1966-04-08       Married      M
# 1            11001        MR. EUGENE HUANG 1965-05-14        Single      M
# 2            11002        MR. RUBEN TORRES 1965-08-12       Married      M
# 3            11003         MS. CHRISTY ZHU 1968-02-15        Single      F
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08        Single      F
# ...            ...                     ...        ...           ...    ...
# 18143        29479          MR. TOMMY TANG 1958-07-04       Married      M
# 18144        29480          MRS. NINA RAJI 1960-11-10        Single      F
# 18145        29481           MR. IVAN SURI 1960-01-05        Single      M
# 18146        29482       MR. CLAYTON ZHANG 1959-03-05       Married      M
# 18147        29483       MR. JÉSUS NAVARRO 1959-12-08       Married      M
#
#                      EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Full Name       18148 non-null  object
#  2   BirthDate       18148 non-null  datetime64[ns]
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  object
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 1.5+ MB

# %%
data.AnnualIncome = data.AnnualIncome.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Full Name       18148 non-null  object
#  2   BirthDate       18148 non-null  datetime64[ns]
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  int32
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: datetime64[ns](1), int32(1), int64(2), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# barchat of Marital status

# %%
data.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married    9817
# Single     8331
# Name: count, dtype: int64

# %%
data.MaritalStatus.value_counts().plot(kind = "bar")
plt.title("Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.countplot(y = "MaritalStatus", data = data)
# Out:
# <Axes: xlabel='count', ylabel='MaritalStatus'>

# %% [markdown]
# pie chart of Gender

# %%
data.Gender.value_counts()
# Out:
# Gender
# M    9189
# F    8959
# Name: count, dtype: int64

# %%
data.Gender.value_counts().plot(kind = "pie")
plt.title("Gender Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
data.groupby(["TotalChildren","EducationLevel"]).size().reset_index()
# Out:
#     TotalChildren       EducationLevel     0
# 0               0            Bachelors  1370
# 1               0      Graduate Degree   745
# 2               0          High School   994
# 3               0      Partial College  1319
# 4               0  Partial High School   652
# 5               1            Bachelors  1351
# 6               1      Graduate Degree   905
# 7               1          High School   248
# 8               1      Partial College  1048
# 9               2            Bachelors   779
# 10              2      Graduate Degree   340
# 11              2          High School   884
# 12              2      Partial College  1235
# 13              2  Partial High School   465
# 14              3            Bachelors   543
# 15              3      Graduate Degree   455
# 16              3          High School   326
# 17              3      Partial College   602
# 18              3  Partial High School   227
# 19              4            Bachelors   715
# ...

# %%
sns.barplot(y = "EducationLevel",x = "TotalChildren", data = data, estimator = np.mean)
plt.title("Average number of childern by Education Level")
plt.xlabel("EducationLevel")
plt.ylabel("Average Number of Children")
# Out:
# Text(0, 0.5, 'Average Number of Children')

# %% [markdown]
# bar chart of average number of student by each educational levels

# %%
sns.countplot(x = "TotalChildren",hue = "EducationLevel", data = data) 
plt.title("Total Children/Educationat Level Distribution")
plt.xlabel("Total Children")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
sns.barplot(y = "AnnualIncome",x = "Occupation", data = data, estimator = np.mean)
plt.title("Average Annual Income for each Occupation")
plt.xlabel("Occupation")
plt.ylabel("Average Annual Income")
# Out:
# Text(0, 0.5, 'Average Annual Income')

# %% [markdown]
# pie chart showing average annual income by each Occupation

# %%
data.Occupation.value_counts()
# Out:
# Occupation
# Professional      5424
# Skilled Manual    4501
# Management        3011
# Clerical          2859
# Manual            2353
# Name: count, dtype: int64

# %%
data.Occupation.value_counts().plot(kind = "pie")
plt.ylabel("Occupation")
# Out:
# Text(0, 0.5, 'Occupation')

# %%
data["Birth Year"] = data.BirthDate.dt.year

# %%
data
# Out:
#        CustomerKey               Full Name  BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG 1966-04-08       Married      M
# 1            11001        MR. EUGENE HUANG 1965-05-14        Single      M
# 2            11002        MR. RUBEN TORRES 1965-08-12       Married      M
# 3            11003         MS. CHRISTY ZHU 1968-02-15        Single      F
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08        Single      F
# ...            ...                     ...        ...           ...    ...
# 18143        29479          MR. TOMMY TANG 1958-07-04       Married      M
# 18144        29480          MRS. NINA RAJI 1960-11-10        Single      F
# 18145        29481           MR. IVAN SURI 1960-01-05        Single      M
# 18146        29482       MR. CLAYTON ZHANG 1959-03-05       Married      M
# 18147        29483       MR. JÉSUS NAVARRO 1959-12-08       Married      M
#
#                      EmailAddress  AnnualIncome  TotalChildren  \
# ...

# %% [markdown]
# Adding age gotten from BirthDate to the table

# %%
data["Age"] = 2024 - data["Birth Year"]

# %%
data
# Out:
#        CustomerKey               Full Name  BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG 1966-04-08       Married      M
# 1            11001        MR. EUGENE HUANG 1965-05-14        Single      M
# 2            11002        MR. RUBEN TORRES 1965-08-12       Married      M
# 3            11003         MS. CHRISTY ZHU 1968-02-15        Single      F
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08        Single      F
# ...            ...                     ...        ...           ...    ...
# 18143        29479          MR. TOMMY TANG 1958-07-04       Married      M
# 18144        29480          MRS. NINA RAJI 1960-11-10        Single      F
# 18145        29481           MR. IVAN SURI 1960-01-05        Single      M
# 18146        29482       MR. CLAYTON ZHANG 1959-03-05       Married      M
# 18147        29483       MR. JÉSUS NAVARRO 1959-12-08       Married      M
#
#                      EmailAddress  AnnualIncome  TotalChildren  \
# ...

# %%
data
# Out:
#        CustomerKey               Full Name  BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG 1966-04-08       Married      M
# 1            11001        MR. EUGENE HUANG 1965-05-14        Single      M
# 2            11002        MR. RUBEN TORRES 1965-08-12       Married      M
# 3            11003         MS. CHRISTY ZHU 1968-02-15        Single      F
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08        Single      F
# ...            ...                     ...        ...           ...    ...
# 18143        29479          MR. TOMMY TANG 1958-07-04       Married      M
# 18144        29480          MRS. NINA RAJI 1960-11-10        Single      F
# 18145        29481           MR. IVAN SURI 1960-01-05        Single      M
# 18146        29482       MR. CLAYTON ZHANG 1959-03-05       Married      M
# 18147        29483       MR. JÉSUS NAVARRO 1959-12-08       Married      M
#
#                      EmailAddress  AnnualIncome  TotalChildren  \
# ...

# %%
data.Age.value_counts().reset_index()
# Out:
#     Age  count
# 0    59    666
# 1    56    661
# 2    57    643
# 3    58    634
# 4    55    633
# ..  ...    ...
# 65  112      2
# 66  101      2
# 67  114      1
# 68  107      1
# 69  109      1
#
# [70 rows x 2 columns]

# %% [markdown]
# histogram showing Age distribution of customers

# %%
sns.histplot(data["Age"], bins = 20)
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# line chart Showing average annual income by age group

# %%
sns.lineplot(x = "Age", y = "AnnualIncome", data = data, estimator = np.mean)
plt.title("Average Annual Income by Age group")
plt.xlabel("Age")
plt.xlabel("Average Annual Income")
# Out:
# Text(0.5, 0, 'Average Annual Income')

# %% [markdown]
# home owners distribution bar chart

# %%
sns.countplot(x = "HomeOwner", data = data)
plt.title("Home Owners Distribution")
plt.xlabel("Home Owners Distribution")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Barchart showing education level of customers

# %%
sns.countplot(y = "EducationLevel", data = data)
plt.title("Education Level Distribution of Customers")
plt.ylabel("Education Level")
plt.xlabel("Count")
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# histogram showing total children distribution

# %%
data.TotalChildren.value_counts().reset_index()
# Out:
#    TotalChildren  count
# 0              0   5080
# 1              2   3703
# 2              1   3552
# 3              4   2259
# 4              3   2153
# 5              5   1401

# %%
sns.histplot(data["TotalChildren"], bins = 20)
plt.title("Total Children distribution")
plt.xlabel("Total Children")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# pie chart showing marital status and occupation distribution

# %%
data.groupby(["MaritalStatus","Occupation"]).size().reset_index()
# Out:
#   MaritalStatus      Occupation     0
# 0       Married        Clerical  1407
# 1       Married      Management  1888
# 2       Married          Manual   791
# 3       Married    Professional  3062
# 4       Married  Skilled Manual  2669
# 5        Single        Clerical  1452
# 6        Single      Management  1123
# 7        Single          Manual  1562
# 8        Single    Professional  2362
# 9        Single  Skilled Manual  1832

# %%
data.groupby(["MaritalStatus","Occupation"]).size().plot(kind = "pie")
# Out:
# <Axes: >

# %% [markdown]
# Bar chart showing education level and gender distribution

# %%
data.groupby(["Gender","EducationLevel"]).size().plot(kind = "barh")
# Out:
# <Axes: ylabel='Gender,EducationLevel'>

# %%
sns.countplot(x = "Gender",hue = "EducationLevel", data = data) 
plt.title("Gender/Education Level Distribution")
plt.xlabel("Gender")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# line chart of average total children by annual income range

# %%
sns.lineplot(y = "TotalChildren", x = "AnnualIncome", data = data, estimator = np.mean)
plt.title("Average Total Children by Annual Income range")
plt.xlabel("Annual Income")
plt.ylabel("Average total children")
# Out:
# Text(0, 0.5, 'Average total children')

# %%
data.groupby(["HomeOwner","MaritalStatus"]).size().reset_index()
# Out:
#   HomeOwner MaritalStatus     0
# 0        No       Married  1816
# 1        No        Single  4072
# 2       Yes       Married  8001
# 3       Yes        Single  4259

# %%
data.groupby(["HomeOwner","MaritalStatus"]).size().plot(kind = "barh")
plt.title("Home Owners and Marital status Distribution chat")
plt.ylabel("Home Owners and Marital Status")
plt.xlabel("count")
# Out:
# Text(0.5, 0, 'count')

# %%
data["Birth month"] = data.BirthDate.dt.month

# %%
data
# Out:
#        CustomerKey               Full Name  BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG 1966-04-08       Married      M
# 1            11001        MR. EUGENE HUANG 1965-05-14        Single      M
# 2            11002        MR. RUBEN TORRES 1965-08-12       Married      M
# 3            11003         MS. CHRISTY ZHU 1968-02-15        Single      F
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08        Single      F
# ...            ...                     ...        ...           ...    ...
# 18143        29479          MR. TOMMY TANG 1958-07-04       Married      M
# 18144        29480          MRS. NINA RAJI 1960-11-10        Single      F
# 18145        29481           MR. IVAN SURI 1960-01-05        Single      M
# 18146        29482       MR. CLAYTON ZHANG 1959-03-05       Married      M
# 18147        29483       MR. JÉSUS NAVARRO 1959-12-08       Married      M
#
#                      EmailAddress  AnnualIncome  TotalChildren  \
# ...

# %%
sns.countplot(y = "Birth month", data = data)
# Out:
# <Axes: xlabel='count', ylabel='Birth month'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Full Name       18148 non-null  object
#  2   BirthDate       18148 non-null  datetime64[ns]
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  int32
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
#  11  Birth Year      18148 non-null  int32
#  12  Age             18148 non-null  int32
#  13  Birth month     18148 non-null  int32
# dtypes: datetime64[ns](1), int32(4), int64(2), object(7)
# memory usage: 1.7+ MB

# %%
sns.countplot(y = "EducationLevel", data = data)
plt.title("Education Level Distribution")
plt.ylabel("Education Level")
plt.xlabel("Count")
# Out:
# Text(0.5, 0, 'Count')

# %%
data.describe()
# Out:
#         CustomerKey                      BirthDate   AnnualIncome  \
# count  18148.000000                          18148   18148.000000
# mean   20247.470465  1962-01-29 07:41:05.329512864   57269.120564
# min    11000.000000            1910-08-13 00:00:00   10000.000000
# 25%    15626.750000            1954-09-11 18:00:00   30000.000000
# 50%    20252.500000            1963-08-20 00:00:00   60000.000000
# 75%    24868.250000            1970-09-26 00:00:00   70000.000000
# max    29483.000000            1980-12-26 00:00:00  170000.000000
# std     5336.245656                            NaN   32236.535573
#
#        TotalChildren    Birth Year           Age   Birth month
# count   18148.000000  18148.000000  18148.000000  18148.000000
# mean        1.843619   1961.584417     62.415583      6.502480
# min         0.000000   1910.000000     44.000000      1.000000
# 25%         0.000000   1954.000000     54.000000      4.000000
# ...
